# %%
print("to jest pierwszy notebook!")
# Out:
# to jest pierwszy notebook!

# %%
informacja = "tworzenie struktur danych dla modeli AI z użyciem: numpy, pandas"

# %%
print(informacja)
# Out:
# tworzenie struktur danych dla modeli AI z użyciem: numpy, pandas

# %%
import datetime
dt_przyjazd = (datetime.date(2024, 10, 24), datetime.date(2024, 10, 27))

# %%
print(dt_przyjazd)
# Out:
# (datetime.date(2024, 10, 24), datetime.date(2024, 10, 27))

# %% [markdown]
# Piszemy **notebook** - <span style="color:red;font-size:16pt;">Jupyter Notebook</span>: przygotowanie struktur danych

# %%
import numpy as np

# %%
listapy = [54,77,37,8,235,9,3,99]
print(listapy)
print(type(listapy))
# Out:
# [54, 77, 37, 8, 235, 9, 3, 99]
# <class 'list'>

# %%
listanp = np.array([7,3567,35678,3223,9,24678,8000])
print(listanp)
print(type(listanp))
# Out:
# [    7  3567 35678  3223     9 24678  8000]
# <class 'numpy.ndarray'>
